# %%
import tensorflow as tf
import numpy as np
x=tf.placeholder(tf.float32,shape=[None,2])
y=tf.placeholder(tf.float32,shape=[None,1])

weights=tf.Variable(tf.random_normal([2,1]),dtype=tf.float32)
bias=tf.Variable(tf.random_normal([1]),dtype=tf.float32)



multiply1=tf.add(tf.matmul(x,weights),bias)
z=tf.nn.sigmoid(multiply1)


cost=tf.reduce_mean((y*tf.log(z)+(1-y)*tf.log(1-z))*-1)
optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

inp=np.array([[0,0],[0,1],[1,0],[1,1]])
op=np.array([[0],[0],[0],[1]])
with tf.Session() as sess:
   
    tf.global_variables_initializer().run()
    for i in range(12001):
        res,_=sess.run([cost,optimizer],feed_dict={x:inp,y:op})
        if i%1000==0:
            print ("iteration= ",i,"cost= ",res)
    print ("Validating output for AND GATE")
    result=sess.run(z,feed_dict={x:inp})
    print (result)
# Out:
# iteration=  0 cost=  0.494346
# iteration=  1000 cost=  0.36538
# iteration=  2000 cost=  0.302366
# iteration=  3000 cost=  0.259595
# iteration=  4000 cost=  0.228185
# iteration=  5000 cost=  0.203882
# iteration=  6000 cost=  0.184387
# iteration=  7000 cost=  0.168334
# iteration=  8000 cost=  0.154851
# iteration=  9000 cost=  0.14335
# iteration=  10000 cost=  0.133414
# iteration=  11000 cost=  0.12474
# iteration=  12000 cost=  0.117099
# Validating output for AND GATE
# [[ 0.00443124]
#  [ 0.12503561]
#  [ 0.12584606]
#  [ 0.82213116]]

# %%
import tensorflow as tf
import numpy as np
x=tf.placeholder(tf.float32,shape=[None,2])
y=tf.placeholder(tf.float32,shape=[None,1])

weights=tf.Variable(tf.random_normal([2,1]),dtype=tf.float32)
bias=tf.Variable(tf.random_normal([1]),dtype=tf.float32)



multiply1=tf.add(tf.matmul(x,weights),bias)
z=tf.nn.sigmoid(multiply1)


cost=tf.reduce_mean((y*tf.log(z)+(1-y)*tf.log(1-z))*-1)
optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

inp=np.array([[0,0],[0,1],[1,0],[1,1]])
op=np.array([[0],[1],[1],[1]])
with tf.Session() as sess:
   
    tf.global_variables_initializer().run()
    for i in range(12001):
        res,_=sess.run([cost,optimizer],feed_dict={x:inp,y:op})
        if i%1000==0:
            print ("iteration= ",i,"cost= ",res)
    print ("Validating output for OR GATE")
    result=sess.run(z,feed_dict={x:inp})
    print (result)
# Out:
# iteration=  0 cost=  0.76827
# iteration=  1000 cost=  0.328813
# iteration=  2000 cost=  0.25769
# iteration=  3000 cost=  0.210956
# iteration=  4000 cost=  0.177817
# iteration=  5000 cost=  0.153205
# iteration=  6000 cost=  0.134262
# iteration=  7000 cost=  0.119268
# iteration=  8000 cost=  0.107131
# iteration=  9000 cost=  0.0971237
# iteration=  10000 cost=  0.0887432
# iteration=  11000 cost=  0.0816322
# iteration=  12000 cost=  0.0755292
# Validating output for OR GATE
# [[ 0.15886831]
#  [ 0.93866366]
#  [ 0.93710405]
#  [ 0.99917233]]

# %%
import tensorflow as tf
import numpy as np
x=tf.placeholder(tf.float32,shape=[None,2])
y=tf.placeholder(tf.float32,shape=[None,1])

#weights=tf.Variable(tf.random_normal([2,1]),dtype=tf.float32)
#bias=tf.Variable(tf.random_normal([1]),dtype=tf.float32)



#multiply1=tf.add(tf.matmul(x,weights),bias)
#z=tf.nn.sigmoid(multiply1)


Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name="Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name="Theta2")
Bias1 = tf.Variable(tf.zeros([2]), name="Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name="Bias2")
A2 = tf.sigmoid(tf.matmul(x, Theta1) + Bias1)
z = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)
    
cost=tf.reduce_mean((y*tf.log(z)+(1-y)*tf.log(1-z))*-1)
optimizer = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

inp=np.array([[0,0],[0,1],[1,0],[1,1]])
op=np.array([[0],[1],[1],[0]])
with tf.Session() as sess:
   
    tf.global_variables_initializer().run()
    for i in range(100000):
        res,_=sess.run([cost,optimizer],feed_dict={x:inp,y:op})
        if i%1000==0:
            print ("iteration = ",i,"cost= ",res)
    print ("Validating output for XOR GATE")
    result=sess.run(z,feed_dict={x:inp})
    print (result)
# Out:
# iteration =  0 cost=  0.697307
# iteration =  1000 cost=  0.694585
# iteration =  2000 cost=  0.694315
# iteration =  3000 cost=  0.6941
# iteration =  4000 cost=  0.693927
# iteration =  5000 cost=  0.693785
# iteration =  6000 cost=  0.693666
# iteration =  7000 cost=  0.693566
# iteration =  8000 cost=  0.693479
# iteration =  9000 cost=  0.693403
# iteration =  10000 cost=  0.693336
# iteration =  11000 cost=  0.693276
# iteration =  12000 cost=  0.69322
# iteration =  13000 cost=  0.693168
# iteration =  14000 cost=  0.693119
# iteration =  15000 cost=  0.693072
# iteration =  16000 cost=  0.693025
# iteration =  17000 cost=  0.692979
# iteration =  18000 cost=  0.692932
# iteration =  19000 cost=  0.692884
# iteration =  20000 cost=  0.692834
# iteration =  21000 cost=  0.692782
# iteration =  22000 cost=  0.692725
# iteration =  23000 cost=  0.692664
# iteration =  24000 cost=  0.692598
# iteration =  25000 cost=  0.692524
# iteration =  26000 cost=  0.692443
